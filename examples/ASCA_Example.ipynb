# %% [markdown]
# <a href="https://colab.research.google.com/github/tsyet12/ASCA/blob/master/examples/ASCA_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ASCA
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ASCA
#   Downloading ASCA-1.0.tar.gz (7.5 kB)
# Building wheels for collected packages: ASCA
#   Building wheel for ASCA (setup.py) ... done
#   Created wheel for ASCA: filename=ASCA-1.0-py3-none-any.whl size=7541 sha256=53b15b1bc66d07f1602b1cbf6a10459e09da450f095ea381688a12cb4ac27887
#   Stored in directory: /root/.cache/pip/wheels/ab/a2/fc/2129a9892d86be0eb22d32267ccec926784c7323a0acb2e0ed
# Successfully built ASCA
# Installing collected packages: ASCA
# Successfully installed ASCA-1.0

# %%
from ASCA.ASCA import ASCA
import numpy as np

#This is the X matrix
X = [[1.0000,0.6000], 
[3.0000,0.4000],
[2.0000,0.7000],
[1.0000,0.8000],
[2.0000,0.0100],
[2.0000,0.8000],
[4.0000,1.0000],
[6.0000,2.0000],
[5.0000,0.9000],
[5.0000,1.0000],
[6.0000,2.0000],
[5.0000,0.7000]]
X=np.asarray(X) #make it numpy friendly

#This is the factor matrix
F = [[1,     1],
  [1,     1],
  [1,     2],
  [1,     2],
  [1,     3],
  [1,     3],
  [2,     1],
  [2,     1],
  [2,     2],
  [2,     2],
  [2,     3],
  [2,     3]] 
F=np.asarray(F)  #make it numpy friendly
interactions = [[0, 1]]  # Which interaction is considered

ASCA=ASCA() #call function
ASCA.fit(X,F,interactions)  #fit method

# %%
# How the variables are syntaxed
ASCA.factors
ASCA.factors_explained
ASCA.factors_loadings
ASCA.factors_projected
ASCA.factors_scores
ASCA.factors_singular

ASCA.interactions
ASCA.interaction_explained
ASCA.interaction_loadings
ASCA.interaction_projected
ASCA.interaction_scores
ASCA.factors_singular

ASCA.residuals
ASCA.effects
# Out:
# array([78.62063716, 17.46930751,  0.27607415,  0.28358955,  3.35039163])

# %%
#Plot factors and interactions
ASCA.plot_factors()
ASCA.plot_interactions()
# Out:
# /usr/local/lib/python3.8/dist-packages/ASCA/ASCA.py:300: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[1].set_xticks(x, labels)
# /usr/local/lib/python3.8/dist-packages/ASCA/ASCA.py:300: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[1].set_xticks(x, labels)
# /usr/local/lib/python3.8/dist-packages/ASCA/ASCA.py:233: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[1].set_xticks(x, labels)
